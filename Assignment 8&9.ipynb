# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex
# count    891.000000  891.000000  891.000000                      891   891  \
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic['Embarked'].fillna('S', inplace=True)

# %%
titanic.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex
# count    891.000000  891.000000  891.000000                      891   891  \
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
titanic['Numberic_Cabin'] = np.where(titanic['Cabin'].isnull(),0,1)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Numberic_Cabin
# 0      0         A/5 21171   7.2500   NaN        S               0
# 1      0          PC 17599  71.2833   C85        C               1
# 2      0  STON/O2. 3101282   7.9250   NaN        S               0
# ...

# %%
mean = titanic['Age'].mean()
mean
# Out:
# 29.69911764705882

# %%
std = titanic['Age'].std()
std
# Out:
# 14.526497332334042

# %%
lower = mean-std
lower
# Out:
# 15.172620314724778

# %%
upper = mean+std
upper
# Out:
# 44.22561497939286

# %%
titanic['Age'].fillna(np.random.randint(lower,upper),inplace=True)

# %%
titanic.isnull().sum()
# Out:
# PassengerId         0
# Survived            0
# Pclass              0
# Name                0
# Sex                 0
# Age                 0
# SibSp               0
# Parch               0
# Ticket              0
# Fare                0
# Cabin             687
# Embarked            0
# Numberic_Cabin      0
# dtype: int64

# %%
titanic['Family'] = titanic['Survived'] + titanic['SibSp']

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Numberic_Cabin  Family
# 0      0         A/5 21171   7.2500   NaN        S               0       1
# 1      0          PC 17599  71.2833   C85        C               1       2
# 2      0  STON/O2. 3101282   7.9250   NaN        S               0       1
# ...

# %%
titanic['Is_Alone'] = np.where(titanic['Family']==1,1,0)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Numberic_Cabin  Family
# 0      0         A/5 21171   7.2500   NaN        S               0       1  \
# 1      0          PC 17599  71.2833   C85        C               1       2
# 2      0  STON/O2. 3101282   7.9250   NaN        S               0       1
# ...

# %%
titanic['Fare_Category'] = pd.cut(titanic['Fare'], bins=4, labels=False) + 1

# %%
titanic['Fare_Category'].unique()
# Out:
# array([1, 3, 2, 4], dtype=int64)

# %%
titanic.drop('Cabin',axis=1,inplace=True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
surv = pd.DataFrame(titanic.groupby('Survived')['PassengerId'].count())

# %%
surv.rename(columns={'PassengerId' : 'No of Passengers'},inplace=True)

# %%
surv
# Out:
#           No of Passengers
# Survived
# 0                      549
# 1                      342

# %%
import matplotlib.pyplot as plt

# %%
surv.dtypes
# Out:
# No of Passengers    int64
# dtype: object

# %%
labels = surv.index
plt.pie(surv['No of Passengers'], labels=labels,autopct='%1.0f%%')
plt.title('Number of People Survived')
plt.legend()
plt.show()

# %%
sns.countplot(x='Survived', data=titanic)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
Pclass = pd.DataFrame(titanic.groupby(['Pclass','Survived'])['PassengerId'].count())

# %%
Pclass
# Out:
#                  PassengerId
# Pclass Survived
# 1      0                  80
#        1                 136
# 2      0                  97
#        1                  87
# 3      0                 372
#        1                 119

# %%
Pclass.rename(columns={'PassengerId' : 'No of Passengers'},inplace=True)

# %%
Pclass
# Out:
#                  No of Passengers
# Pclass Survived
# 1      0                       80
#        1                      136
# 2      0                       97
#        1                       87
# 3      0                      372
#        1                      119

# %%
sns.countplot(x='Pclass',data=titanic, hue='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.histplot(x='Fare', hue='Pclass', data=titanic, binwidth=30)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
 sns.boxplot(x='Pclass',y='Age',data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.violinplot(x='Pclass',y='Age',data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>
